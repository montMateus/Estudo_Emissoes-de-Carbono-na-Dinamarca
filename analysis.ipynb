# %%
import pandas as pd
from sqlalchemy import create_engine, text
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D

# %%
db_user = 'postgres'
db_password = '123456'
db_host = 'localhost'
db_port = '5432'
db_name = 'nordic_co2'

engine = create_engine(f'postgresql+psycopg2://{db_user}:{db_password}@{db_host}:{db_port}/{db_name}')

# %% [markdown]
# # Denmark

# %% [markdown]
# ## General Analysis

# %%
query_dk_general = '''
WITH dk_2021_summary AS (
    SELECT 
        '2021' AS year_,
        country,
        zone_id,
        EXTRACT(MONTH FROM datetime_utc) AS month_grouped,
        ROUND(SUM(carbon_intensity_direct)::NUMERIC, 2) AS total_direct_carbon_emission,
        ROUND(SUM(carbon_intensity_lca)::NUMERIC, 2) AS total_lca_carbon_emission,
        ROUND(AVG(renewable_percentage)::NUMERIC, 2) AS avg_renewable_percentage,
        ROUND(AVG(low_carbon_percentage)::NUMERIC, 2) AS avg_low_carbon_percentage
    FROM denmark.year_2021_hourly
    GROUP BY country, zone_id, EXTRACT(MONTH FROM datetime_utc)
), dk_2022_summary AS (
    SELECT 
        '2022' AS year_,
        country,
        zone_id,
        EXTRACT(MONTH FROM datetime_utc) AS month_grouped,
        ROUND(SUM(carbon_intensity_direct)::NUMERIC, 2) AS total_direct_carbon_emission,
        ROUND(SUM(carbon_intensity_lca)::NUMERIC, 2) AS total_lca_carbon_emission,
        ROUND(AVG(renewable_percentage)::NUMERIC, 2) AS avg_renewable_percentage,
        ROUND(AVG(low_carbon_percentage)::NUMERIC, 2) AS avg_low_carbon_percentage
    FROM denmark.year_2022_hourly
    GROUP BY country, zone_id, EXTRACT(MONTH FROM datetime_utc)
), dk_2023_summary AS (
    SELECT 
        '2023' AS year_,
        country,
        zone_id,
        EXTRACT(MONTH FROM datetime_utc) AS month_grouped,
        ROUND(SUM(carbon_intensity_direct)::NUMERIC, 2) AS total_direct_carbon_emission,
        ROUND(SUM(carbon_intensity_lca)::NUMERIC, 2) AS total_lca_carbon_emission,
        ROUND(AVG(renewable_percentage)::NUMERIC, 2) AS avg_renewable_percentage,
        ROUND(AVG(low_carbon_percentage)::NUMERIC, 2) AS avg_low_carbon_percentage
    FROM denmark.year_2023_hourly
    GROUP BY country, zone_id, EXTRACT(MONTH FROM datetime_utc)
), dk_2024_summary AS (
    SELECT 
        '2024' AS year_,
        country,
        zone_id,
        EXTRACT(MONTH FROM datetime_utc) AS month_grouped,
        ROUND(SUM(carbon_intensity_direct)::NUMERIC, 2) AS total_direct_carbon_emission,
        ROUND(SUM(carbon_intensity_lca)::NUMERIC, 2) AS total_lca_carbon_emission,
        ROUND(AVG(renewable_percentage)::NUMERIC, 2) AS avg_renewable_percentage,
        ROUND(AVG(low_carbon_percentage)::NUMERIC, 2) AS avg_low_carbon_percentage
    FROM denmark.year_2024_hourly
    GROUP BY country, zone_id, EXTRACT(MONTH FROM datetime_utc)
), total_summary AS (
    SELECT * FROM dk_2021_summary
    UNION ALL
    SELECT * FROM dk_2022_summary
    UNION ALL
    SELECT * FROM dk_2023_summary
    UNION ALL
    SELECT * FROM dk_2024_summary
), with_differences AS (
    SELECT 
        *,
        LEAD(total_direct_carbon_emission) OVER (PARTITION BY country, zone_id ORDER BY year_, month_grouped) AS next_direct_carbon_emission,
        LEAD(total_lca_carbon_emission) OVER (PARTITION BY country, zone_id ORDER BY year_, month_grouped) AS next_lca_carbon_emission
    FROM total_summary
)

SELECT 
    year_,
    country,
    zone_id,
    month_grouped,
    total_direct_carbon_emission,
    next_direct_carbon_emission,
    CASE 
        WHEN next_direct_carbon_emission IS NOT NULL AND total_direct_carbon_emission != 0 
        THEN ROUND(((next_direct_carbon_emission - total_direct_carbon_emission) / total_direct_carbon_emission) * 100::NUMERIC, 2)
        ELSE NULL 
    END AS direct_decrease_or_increase,
    total_lca_carbon_emission,
    next_lca_carbon_emission,
    CASE 
        WHEN next_lca_carbon_emission IS NOT NULL AND total_lca_carbon_emission != 0 
        THEN ROUND(((next_lca_carbon_emission - total_lca_carbon_emission) / total_lca_carbon_emission) * 100::NUMERIC, 2)
        ELSE NULL 
    END AS lca_decrease_or_increase,
    avg_renewable_percentage,
    avg_low_carbon_percentage
FROM with_differences
ORDER BY year_, month_grouped;
'''

dk_general = pd.read_sql_query(query_dk_general, engine)

# %%
dk_general.head()
# Out:
#   year_  country zone_id  month_grouped  total_direct_carbon_emission  \
# 0  2021  Denmark      DK            1.0                     158574.07
# 1  2021  Denmark      DK            2.0                     140536.32
# 2  2021  Denmark      DK            3.0                     114471.01
# 3  2021  Denmark      DK            4.0                      87814.07
# 4  2021  Denmark      DK            5.0                      77478.25
#
#    next_direct_carbon_emission  direct_decrease_or_increase  \
# 0                    140536.32                       -11.37
# 1                    114471.01                       -18.55
# 2                     87814.07                       -23.29
# 3                     77478.25                       -11.77
# 4                     89436.53                        15.43
#
#    total_lca_carbon_emission  next_lca_carbon_emission  \
# 0                  215154.47                 190412.53
# 1                  190412.53                 164417.37
# 2                  164417.37                 136052.60
# 3                  136052.60                 125661.22
# 4                  125661.22                 132249.17
#
#    lca_decrease_or_increase  avg_renewable_percentage  \
# 0                    -11.50                     64.98
# 1                    -13.65                     65.89
# 2                    -17.25                     72.72
# 3                     -7.64                     76.53
# 4                      5.24                     77.06
#
#    avg_low_carbon_percentage
# 0                      69.88
# 1                      70.02
# 2                      77.84
# 3                      82.41
# 4                      84.52

# %%
dk_general.rename(columns={'year_':'year'}, inplace=True)
dk_general.rename(columns={'month_grouped':'month'}, inplace=True)

# %%
dk_general.dtypes
# Out:
# year                             object
# country                          object
# zone_id                          object
# month                           float64
# total_direct_carbon_emission    float64
# next_direct_carbon_emission     float64
# direct_decrease_or_increase     float64
# total_lca_carbon_emission       float64
# next_lca_carbon_emission        float64
# lca_decrease_or_increase        float64
# avg_renewable_percentage        float64
# avg_low_carbon_percentage       float64
# dtype: object

# %%
dk_general.year = dk_general.year.astype(int)
dk_general.month = dk_general.month.astype(int)

# %% [markdown]
# ### Statistics

# %%
dk_general.describe()
# Out:
#               year      month  total_direct_carbon_emission  \
# count    48.000000  48.000000                     48.000000
# mean   2022.500000   6.500000                  77288.009583
# std       1.129865   3.488583                  31752.364778
# min    2021.000000   1.000000                  31842.110000
# 25%    2021.750000   3.750000                  50007.835000
# 50%    2022.500000   6.500000                  77426.890000
# 75%    2023.250000   9.250000                  99124.767500
# max    2024.000000  12.000000                 158574.070000
#
#        next_direct_carbon_emission  direct_decrease_or_increase  \
# count                    47.000000                    47.000000
# mean                  75558.518936                     2.218723
# std                   29722.626553                    33.866039
# min                   31842.110000                   -39.230000
# 25%                   49366.540000                   -22.765000
# 50%                   77375.530000                   -11.440000
# 75%                   98716.805000                    22.925000
# max                  140536.320000                   124.380000
#
#        total_lca_carbon_emission  next_lca_carbon_emission  \
# count                   48.00000                 47.000000
# mean                116871.50625             114780.379362
# std                  37983.76014              35491.866951
# min                  61812.86000              61812.860000
# 25%                  85270.95000              84044.880000
# 50%                 120109.66500             119795.510000
# 75%                 141154.87500             138198.285000
# max                 215154.47000             190412.530000
#
#        lca_decrease_or_increase  avg_renewable_percentage  \
# count                 47.000000                 48.000000
# mean                   0.933404                 76.992500
# std                   26.289207                  4.486074
# min                  -33.760000                 64.980000
# 25%                  -17.045000                 74.452500
# 50%                   -9.380000                 77.065000
# 75%                   18.600000                 79.735000
# max                   98.290000                 84.780000
#
#        avg_low_carbon_percentage
# count                  48.000000
# mean                   84.050833
# std                     5.484828
# min                    69.880000
# 25%                    81.102500
# 50%                    84.350000
# 75%                    88.580000
# max                    92.280000

# %%
sns.boxplot(dk_general[['total_direct_carbon_emission', 'total_lca_carbon_emission']])
# Out:
# <Axes: >

# %%
sns.boxplot(dk_general[['direct_decrease_or_increase', 'lca_decrease_or_increase']])
# Out:
# <Axes: >

# %%
dk_general[dk_general['direct_decrease_or_increase'] > 100]
# Out:
#     year  country zone_id  month  total_direct_carbon_emission  \
# 33  2023  Denmark      DK     10                      37574.31
#
#     next_direct_carbon_emission  direct_decrease_or_increase  \
# 33                     84310.08                       124.38
#
#     total_lca_carbon_emission  next_lca_carbon_emission  \
# 33                   61812.86                 122570.52
#
#     lca_decrease_or_increase  avg_renewable_percentage  \
# 33                     98.29                      83.4
#
#     avg_low_carbon_percentage
# 33                      91.18

# %%
dk_general.loc[[33, 34]]
# Out:
#     year  country zone_id  month  total_direct_carbon_emission  \
# 33  2023  Denmark      DK     10                      37574.31
# 34  2023  Denmark      DK     11                      84310.08
#
#     next_direct_carbon_emission  direct_decrease_or_increase  \
# 33                     84310.08                       124.38
# 34                     99659.48                        18.21
#
#     total_lca_carbon_emission  next_lca_carbon_emission  \
# 33                   61812.86                 122570.52
# 34                  122570.52                 143587.59
#
#     lca_decrease_or_increase  avg_renewable_percentage  \
# 33                     98.29                     83.40
# 34                     17.15                     73.97
#
#     avg_low_carbon_percentage
# 33                      91.18
# 34                      80.67

# %%
dk_general.select_dtypes(include='number').corr()
# Out:
#                                       year         month  \
# year                          1.000000e+00  4.864312e-14
# month                         4.864312e-14  1.000000e+00
# total_direct_carbon_emission -6.879429e-01 -1.488934e-01
# next_direct_carbon_emission  -7.171628e-01  9.259424e-02
# direct_decrease_or_increase   3.334578e-03  3.015244e-01
# total_lca_carbon_emission    -6.799415e-01 -1.650307e-01
# next_lca_carbon_emission     -7.086851e-01  7.560204e-02
# lca_decrease_or_increase      3.222868e-03  3.075360e-01
# avg_renewable_percentage      5.781040e-01  1.612530e-01
# avg_low_carbon_percentage     5.559895e-01  2.142640e-01
#
#                               total_direct_carbon_emission  \
# year                                             -0.687943
# month                                            -0.148893
# total_direct_carbon_emission                      1.000000
# next_direct_carbon_emission                       0.711213
# direct_decrease_or_increase                      -0.387034
# total_lca_carbon_emission                         0.993927
# next_lca_carbon_emission                          0.718458
# lca_decrease_or_increase                         -0.365079
# avg_renewable_percentage                         -0.925733
# avg_low_carbon_percentage                        -0.968527
#
#                               next_direct_carbon_emission  \
# year                                            -0.717163
# month                                            0.092594
# total_direct_carbon_emission                     0.711213
# next_direct_carbon_emission                      1.000000
# direct_decrease_or_increase                      0.317112
# total_lca_carbon_emission                        0.698645
# next_lca_carbon_emission                         0.992917
# lca_decrease_or_increase                         0.339322
# avg_renewable_percentage                        -0.599521
# avg_low_carbon_percentage                       -0.647747
#
#                               direct_decrease_or_increase  \
# year                                             0.003335
# month                                            0.301524
# total_direct_carbon_emission                    -0.387034
# next_direct_carbon_emission                      0.317112
# direct_decrease_or_increase                      1.000000
# total_lca_carbon_emission                       -0.403564
# next_lca_carbon_emission                         0.296774
# lca_decrease_or_increase                         0.983378
# avg_renewable_percentage                         0.445120
# avg_low_carbon_percentage                        0.435658
#
#                               total_lca_carbon_emission  \
# year                                          -0.679942
# month                                         -0.165031
# total_direct_carbon_emission                   0.993927
# next_direct_carbon_emission                    0.698645
# direct_decrease_or_increase                   -0.403564
# total_lca_carbon_emission                      1.000000
# next_lca_carbon_emission                       0.712195
# lca_decrease_or_increase                      -0.388810
# avg_renewable_percentage                      -0.916880
# avg_low_carbon_percentage                     -0.972109
#
#                               next_lca_carbon_emission  \
# year                                         -0.708685
# month                                         0.075602
# total_direct_carbon_emission                  0.718458
# next_direct_carbon_emission                   0.992917
# direct_decrease_or_increase                   0.296774
# total_lca_carbon_emission                     0.712195
# next_lca_carbon_emission                      1.000000
# lca_decrease_or_increase                      0.329684
# avg_renewable_percentage                     -0.605734
# avg_low_carbon_percentage                    -0.666691
#
#                               lca_decrease_or_increase  \
# year                                          0.003223
# month                                         0.307536
# total_direct_carbon_emission                 -0.365079
# next_direct_carbon_emission                   0.339322
# direct_decrease_or_increase                   0.983378
# total_lca_carbon_emission                    -0.388810
# next_lca_carbon_emission                      0.329684
# lca_decrease_or_increase                      1.000000
# avg_renewable_percentage                      0.415244
# avg_low_carbon_percentage                     0.408821
#
#                               avg_renewable_percentage  \
# year                                          0.578104
# month                                         0.161253
# total_direct_carbon_emission                 -0.925733
# next_direct_carbon_emission                  -0.599521
# direct_decrease_or_increase                   0.445120
# total_lca_carbon_emission                    -0.916880
# next_lca_carbon_emission                     -0.605734
# lca_decrease_or_increase                      0.415244
# avg_renewable_percentage                      1.000000
# avg_low_carbon_percentage                     0.921628
#
#                               avg_low_carbon_percentage
# year                                           0.555989
# month                                          0.214264
# total_direct_carbon_emission                  -0.968527
# next_direct_carbon_emission                   -0.647747
# direct_decrease_or_increase                    0.435658
# total_lca_carbon_emission                     -0.972109
# next_lca_carbon_emission                      -0.666691
# lca_decrease_or_increase                       0.408821
# avg_renewable_percentage                       0.921628
# avg_low_carbon_percentage                      1.000000

# %%
#sns.pairplot(dk_general)

# %% [markdown]
# ## Hourly Analysis

# %%
query_dk_hourly = '''
WITH dk_2021_summary AS (
    SELECT 
        '2021' AS year_,
        country,
        zone_id,
        EXTRACT(HOUR FROM datetime_utc) AS hour_grouped,
        ROUND(SUM(carbon_intensity_direct)::NUMERIC, 2) AS total_direct_carbon_emission,
        ROUND(SUM(carbon_intensity_lca)::NUMERIC, 2) AS total_lca_carbon_emission,
        ROUND(AVG(renewable_percentage)::NUMERIC, 2) AS avg_renewable_percentage,
        ROUND(AVG(low_carbon_percentage)::NUMERIC, 2) AS avg_low_carbon_percentage
    FROM denmark.year_2021_hourly
    GROUP BY country, zone_id, EXTRACT(HOUR FROM datetime_utc)
), dk_2022_summary AS (
    SELECT 
        '2022' AS year_,
        country,
        zone_id,
        EXTRACT(HOUR FROM datetime_utc) AS hour_grouped,
        ROUND(SUM(carbon_intensity_direct)::NUMERIC, 2) AS total_direct_carbon_emission,
        ROUND(SUM(carbon_intensity_lca)::NUMERIC, 2) AS total_lca_carbon_emission,
        ROUND(AVG(renewable_percentage)::NUMERIC, 2) AS avg_renewable_percentage,
        ROUND(AVG(low_carbon_percentage)::NUMERIC, 2) AS avg_low_carbon_percentage
    FROM denmark.year_2022_hourly
    GROUP BY country, zone_id, EXTRACT(HOUR FROM datetime_utc)
), dk_2023_summary AS (
    SELECT 
        '2023' AS year_,
        country,
        zone_id,
        EXTRACT(HOUR FROM datetime_utc) AS hour_grouped,
        ROUND(SUM(carbon_intensity_direct)::NUMERIC, 2) AS total_direct_carbon_emission,
        ROUND(SUM(carbon_intensity_lca)::NUMERIC, 2) AS total_lca_carbon_emission,
        ROUND(AVG(renewable_percentage)::NUMERIC, 2) AS avg_renewable_percentage,
        ROUND(AVG(low_carbon_percentage)::NUMERIC, 2) AS avg_low_carbon_percentage
    FROM denmark.year_2023_hourly
    GROUP BY country, zone_id, EXTRACT(HOUR FROM datetime_utc)
), dk_2024_summary AS (
    SELECT 
        '2024' AS year_,
        country,
        zone_id,
        EXTRACT(HOUR FROM datetime_utc) AS hour_grouped,
        ROUND(SUM(carbon_intensity_direct)::NUMERIC, 2) AS total_direct_carbon_emission,
        ROUND(SUM(carbon_intensity_lca)::NUMERIC, 2) AS total_lca_carbon_emission,
        ROUND(AVG(renewable_percentage)::NUMERIC, 2) AS avg_renewable_percentage,
        ROUND(AVG(low_carbon_percentage)::NUMERIC, 2) AS avg_low_carbon_percentage
    FROM denmark.year_2024_hourly
    GROUP BY country, zone_id, EXTRACT(HOUR FROM datetime_utc)
), total_summary AS (
    SELECT * FROM dk_2021_summary
    UNION ALL
    SELECT * FROM dk_2022_summary
    UNION ALL
    SELECT * FROM dk_2023_summary
    UNION ALL
    SELECT * FROM dk_2024_summary
), with_differences AS (
    SELECT 
        *,
        LEAD(total_direct_carbon_emission) OVER (PARTITION BY country, zone_id ORDER BY year_, hour_grouped) AS next_direct_carbon_emission,
        LEAD(total_lca_carbon_emission) OVER (PARTITION BY country, zone_id ORDER BY year_, hour_grouped) AS next_lca_carbon_emission
    FROM total_summary
)

SELECT 
    year_,
    country,
    zone_id,
    hour_grouped,
    total_direct_carbon_emission,
    next_direct_carbon_emission,
    CASE 
        WHEN next_direct_carbon_emission IS NOT NULL AND total_direct_carbon_emission != 0 
        THEN ROUND(((next_direct_carbon_emission - total_direct_carbon_emission) / total_direct_carbon_emission) * 100::NUMERIC, 2)
        ELSE NULL 
    END AS direct_decrease_or_increase,
    total_lca_carbon_emission,
    next_lca_carbon_emission,
    CASE 
        WHEN next_lca_carbon_emission IS NOT NULL AND total_lca_carbon_emission != 0 
        THEN ROUND(((next_lca_carbon_emission - total_lca_carbon_emission) / total_lca_carbon_emission) * 100::NUMERIC, 2)
        ELSE NULL 
    END AS lca_decrease_or_increase,
    avg_renewable_percentage,
    avg_low_carbon_percentage
FROM with_differences
ORDER BY year_, hour_grouped
'''

dk_hourly = pd.read_sql_query(query_dk_hourly, engine)

# %%
dk_hourly.head()
# Out:
#   year_  country zone_id  hour_grouped  total_direct_carbon_emission  \
# 0  2021  Denmark      DK           0.0                      47878.73
# 1  2021  Denmark      DK           1.0                      48071.69
# 2  2021  Denmark      DK           2.0                      48788.07
# 3  2021  Denmark      DK           3.0                      49709.44
# 4  2021  Denmark      DK           4.0                      53265.05
#
#    next_direct_carbon_emission  direct_decrease_or_increase  \
# 0                     48071.69                         0.40
# 1                     48788.07                         1.49
# 2                     49709.44                         1.89
# 3                     53265.05                         7.15
# 4                     56412.27                         5.91
#
#    total_lca_carbon_emission  next_lca_carbon_emission  \
# 0                   69894.78                  70231.37
# 1                   70231.37                  71076.02
# 2                   71076.02                  72060.32
# 3                   72060.32                  76131.15
# 4                   76131.15                  79774.19
#
#    lca_decrease_or_increase  avg_renewable_percentage  \
# 0                      0.48                     73.90
# 1                      1.20                     73.71
# 2                      1.38                     73.48
# 3                      5.65                     73.41
# 4                      4.79                     72.93
#
#    avg_low_carbon_percentage
# 0                      82.16
# 1                      82.04
# 2                      81.79
# 3                      81.39
# 4                      79.94

# %%
dk_hourly.rename(columns={'year_':'year'}, inplace=True)
dk_hourly.rename(columns={'hour_grouped':'hour'}, inplace=True)

# %%
dk_hourly.year = dk_hourly.year.astype(int)
dk_hourly.hour = dk_hourly.hour.astype(int)

# %%
dk_hourly.to_excel('dk_hourly.xlsx')

# %%
dk_hourly.describe()
# Out:
#               year       hour  total_direct_carbon_emission  \
# count    96.000000  96.000000                     96.000000
# mean   2022.500000  11.500000                  38644.004792
# std       1.123903   6.958524                  11518.723110
# min    2021.000000   0.000000                  23954.830000
# 25%    2021.750000   5.750000                  27667.392500
# 50%    2022.500000  11.500000                  38077.565000
# 75%    2023.250000  17.250000                  48502.732500
# max    2024.000000  23.000000                  57900.660000
#
#        next_direct_carbon_emission  direct_decrease_or_increase  \
# count                    95.000000                    95.000000
# mean                  38546.797158                    -0.557053
# std                   11540.177486                     5.340443
# min                   23954.830000                   -38.680000
# 25%                   27655.395000                    -2.695000
# 50%                   32404.190000                    -0.170000
# 75%                   48597.845000                     1.990000
# max                   57900.660000                     7.520000
#
#        total_lca_carbon_emission  next_lca_carbon_emission  \
# count                  96.000000                 95.000000
# mean                58435.753125              58315.131789
# std                 13578.099561              13598.327233
# min                 40454.340000              40454.340000
# 25%                 45680.895000              45614.830000
# 50%                 57441.895000              51343.150000
# 75%                 70262.210000              70264.210000
# max                 81481.430000              81481.430000
#
#        lca_decrease_or_increase  avg_renewable_percentage  \
# count                 95.000000                 96.000000
# mean                  -0.471158                 76.993854
# std                    4.227428                  3.248793
# min                  -30.560000                 72.470000
# 25%                   -2.175000                 74.027500
# 50%                   -0.200000                 77.455000
# 75%                    1.425000                 78.555000
# max                    5.650000                 84.370000
#
#        avg_low_carbon_percentage
# count                  96.000000
# mean                   84.066979
# std                     3.287935
# min                    77.820000
# 25%                    81.435000
# 50%                    84.120000
# 75%                    87.052500
# max                    88.760000

# %%
sns.boxplot(dk_hourly[['total_direct_carbon_emission']])
# Out:
# <Axes: >

# %%
sns.boxplot(dk_hourly[['direct_decrease_or_increase']])
# Out:
# <Axes: >

# %%
dk_hourly.select_dtypes(include='number').corr()
# Out:
#                                       year          hour  \
# year                          1.000000e+00  2.451147e-14
# hour                          2.451147e-14  1.000000e+00
# total_direct_carbon_emission -9.431836e-01  2.068594e-02
# next_direct_carbon_emission  -9.273971e-01 -2.923452e-02
# direct_decrease_or_increase   4.479287e-02 -4.011133e-01
# total_lca_carbon_emission    -9.460251e-01  2.501350e-02
# next_lca_carbon_emission     -9.283741e-01 -3.047332e-02
# lca_decrease_or_increase      5.334547e-02 -4.350311e-01
# avg_renewable_percentage      7.911613e-01  1.561477e-02
# avg_low_carbon_percentage     9.184448e-01 -5.817978e-02
#
#                               total_direct_carbon_emission  \
# year                                             -0.943184
# hour                                              0.020686
# total_direct_carbon_emission                      1.000000
# next_direct_carbon_emission                       0.981653
# direct_decrease_or_increase                      -0.058924
# total_lca_carbon_emission                         0.999135
# next_lca_carbon_emission                          0.980158
# lca_decrease_or_increase                         -0.061985
# avg_renewable_percentage                         -0.844075
# avg_low_carbon_percentage                        -0.981932
#
#                               next_direct_carbon_emission  \
# year                                            -0.927397
# hour                                            -0.029235
# total_direct_carbon_emission                     0.981653
# next_direct_carbon_emission                      1.000000
# direct_decrease_or_increase                      0.128501
# total_lca_carbon_emission                        0.981647
# next_lca_carbon_emission                         0.999139
# lca_decrease_or_increase                         0.125915
# avg_renewable_percentage                        -0.820551
# avg_low_carbon_percentage                       -0.965191
#
#                               direct_decrease_or_increase  \
# year                                             0.044793
# hour                                            -0.401113
# total_direct_carbon_emission                    -0.058924
# next_direct_carbon_emission                      0.128501
# direct_decrease_or_increase                      1.000000
# total_lca_carbon_emission                       -0.054881
# next_lca_carbon_emission                         0.132084
# lca_decrease_or_increase                         0.996242
# avg_renewable_percentage                         0.103941
# avg_low_carbon_percentage                        0.052703
#
#                               total_lca_carbon_emission  \
# year                                          -0.946025
# hour                                           0.025013
# total_direct_carbon_emission                   0.999135
# next_direct_carbon_emission                    0.981647
# direct_decrease_or_increase                   -0.054881
# total_lca_carbon_emission                      1.000000
# next_lca_carbon_emission                       0.981743
# lca_decrease_or_increase                      -0.058446
# avg_renewable_percentage                      -0.832820
# avg_low_carbon_percentage                     -0.984402
#
#                               next_lca_carbon_emission  \
# year                                         -0.928374
# hour                                         -0.030473
# total_direct_carbon_emission                  0.980158
# next_direct_carbon_emission                   0.999139
# direct_decrease_or_increase                   0.132084
# total_lca_carbon_emission                     0.981743
# next_lca_carbon_emission                      1.000000
# lca_decrease_or_increase                      0.130159
# avg_renewable_percentage                     -0.809678
# avg_low_carbon_percentage                    -0.967287
#
#                               lca_decrease_or_increase  \
# year                                          0.053345
# hour                                         -0.435031
# total_direct_carbon_emission                 -0.061985
# next_direct_carbon_emission                   0.125915
# direct_decrease_or_increase                   0.996242
# total_lca_carbon_emission                    -0.058446
# next_lca_carbon_emission                      0.130159
# lca_decrease_or_increase                      1.000000
# avg_renewable_percentage                      0.100642
# avg_low_carbon_percentage                     0.053074
#
#                               avg_renewable_percentage  \
# year                                          0.791161
# hour                                          0.015615
# total_direct_carbon_emission                 -0.844075
# next_direct_carbon_emission                  -0.820551
# direct_decrease_or_increase                   0.103941
# total_lca_carbon_emission                    -0.832820
# next_lca_carbon_emission                     -0.809678
# lca_decrease_or_increase                      0.100642
# avg_renewable_percentage                      1.000000
# avg_low_carbon_percentage                     0.848420
#
#                               avg_low_carbon_percentage
# year                                           0.918445
# hour                                          -0.058180
# total_direct_carbon_emission                  -0.981932
# next_direct_carbon_emission                   -0.965191
# direct_decrease_or_increase                    0.052703
# total_lca_carbon_emission                     -0.984402
# next_lca_carbon_emission                      -0.967287
# lca_decrease_or_increase                       0.053074
# avg_renewable_percentage                       0.848420
# avg_low_carbon_percentage                      1.000000

# %%
correlation = dk_hourly.year.corr(dk_hourly.total_direct_carbon_emission)

sns.scatterplot(data=dk_hourly, x='year', y='total_direct_carbon_emission')
plt.title(f'Granularidade por Horas: Ano | Emissão Direta - Coef de Correlação Ano X Emissão Direta: {correlation:.2f} = Negativo Alto')
plt.xlabel('Ano')
plt.ylabel('Emissão Direta (gCO₂/kWh)')
plt.show()

# %%
sns.scatterplot(data=dk_general, x='year', y='total_direct_carbon_emission')
plt.title('Granularidade por Mês: Ano | Emissão Direta')
plt.show()

# %%
sns.pairplot(dk_hourly[['year', 'total_direct_carbon_emission']])

# %% [markdown]
# ### 2021

# %%
dk_hourly_2021 = dk_hourly[dk_hourly.year == 2021]

correlation = dk_hourly_2021.hour.corr(dk_hourly_2021.total_direct_carbon_emission)
mean = dk_hourly_2021.total_direct_carbon_emission.mean()
median = dk_hourly_2021.total_direct_carbon_emission.median()
std = dk_hourly_2021.total_direct_carbon_emission.std()
variance = std**2
cv = (std/mean)*100

plt.figure(figsize=(15, 4))
plt.plot(dk_hourly_2021.hour, dk_hourly_2021.total_direct_carbon_emission, 
         linewidth=1.5, color='#00347c', marker='o', markersize=7, 
         markerfacecolor='white', markeredgewidth=1)

plt.axhline(mean, color='#2680d3', linestyle='dotted', linewidth=2, label=f'Média: {mean:.2f} gCO₂/kWh')
plt.axhline(median, color='#d88523', linestyle='dashdot', linewidth=2, label=f'Mediana: {median:.2f} gCO₂/kWh')

custom_lines = [
    Line2D([0], [0], color='none', label=f'Variância: {variance:.2f} (gCO₂/kWh)²'),
    Line2D([0], [0], color='none', label=f'Desvio Padrão: {std:.2f} gCO₂/kWh'),
    Line2D([0], [0], color='none', label=f'CV: {cv:.2f}%')
]

plt.legend(handles=plt.gca().get_legend_handles_labels()[0] + custom_lines)

plt.title(f'Dinamarca - Emissão Direta por Hora - 2021 | Coef. de Correlação Hora x Emissão Direta = {correlation:.2f} (Baixo)')
plt.xlabel('Hora')
plt.ylabel('Emissão Direta (gCO₂/kWh)')
plt.xticks(range(24))
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.hist(dk_hourly_2021.total_direct_carbon_emission, bins=30, color='#2680d3', edgecolor='black')
plt.axvline(dk_hourly_2021.total_direct_carbon_emission.mean(), color='#00347c', linestyle='dashed', linewidth=2, label=f'Média: {dk_hourly_2021.total_direct_carbon_emission.mean():.2f}')
plt.axvline(dk_hourly_2021.total_direct_carbon_emission.median(), color='#d88523', linestyle='dotted', linewidth=2, label=f'Mediana: {dk_hourly_2021.total_direct_carbon_emission.median():.2f}')
plt.title('Dinamarca - Histograma - Distribuição das Emissões Diretas (2022)')
plt.xlabel('Emissão Direta (gCO₂/kWh)')
plt.ylabel('Frequência')
plt.legend()
plt.tight_layout()
plt.show()

# %%
sns.boxplot(dk_hourly_2021.total_direct_carbon_emission)
# Out:
# <Axes: ylabel='total_direct_carbon_emission'>

# %%
dk_hourly.groupby('hour')['total_direct_carbon_emission'].max().reset_index().sort_values('total_direct_carbon_emission', ascending=False)
# Out:
#     hour  total_direct_carbon_emission
# 16    16                      57900.66
# 6      6                      57887.97
# 7      7                      57763.43
# 17    17                      57042.47
# 5      5                      56412.27
# 8      8                      56183.16
# 15    15                      56123.30
# 18    18                      55346.65
# 9      9                      54215.60
# 19    19                      53865.91
# 14    14                      53520.00
# 4      4                      53265.05
# 10    10                      53057.07
# 11    11                      52393.53
# 13    13                      52220.24
# 20    20                      51792.42
# 12    12                      51783.90
# 3      3                      49709.44
# 21    21                      49011.70
# 2      2                      48788.07
# 22    22                      48218.19
# 23    23                      48178.44
# 1      1                      48071.69
# 0      0                      47878.73

# %% [markdown]
# ### 2022

# %%
dk_hourly_2022 = dk_hourly[dk_hourly.year == 2022]

correlation = dk_hourly_2022.hour.corr(dk_hourly_2022.total_direct_carbon_emission)
mean = dk_hourly_2022.total_direct_carbon_emission.mean()
median = dk_hourly_2022.total_direct_carbon_emission.median()
std = dk_hourly_2022.total_direct_carbon_emission.std()
variance = std**2
cv = (std/mean)*100

plt.figure(figsize=(15, 4))
plt.plot(dk_hourly_2022.hour, dk_hourly_2022.total_direct_carbon_emission, 
         linewidth=1.5, color='#00347c', marker='o', markersize=7, 
         markerfacecolor='white', markeredgewidth=1)

plt.axhline(mean, color='#2680d3', linestyle='dotted', linewidth=2, label=f'Média: {mean:.2f} gCO₂/kWh')
plt.axhline(median, color='#d88523', linestyle='dashdot', linewidth=2, label=f'Mediana: {median:.2f} gCO₂/kWh')

custom_lines = [
    Line2D([0], [0], color='none', label=f'Variância: {variance:.2f} (gCO₂/kWh)²'),
    Line2D([0], [0], color='none', label=f'Desvio Padrão: {std:.2f} gCO₂/kWh'),
    Line2D([0], [0], color='none', label=f'CV: {cv:.2f}%')
]

plt.legend(handles=plt.gca().get_legend_handles_labels()[0] + custom_lines)

plt.title(f'Dinamarca - Emissão Direta por Hora - 2022 | Coef. de Correlação Hora x Emissão Direta = {correlation:.2f} (Baixo)')
plt.xlabel('Hora')
plt.ylabel('Emissão Direta (gCO₂/kWh)')
plt.xticks(range(24))
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.hist(dk_hourly_2022.total_direct_carbon_emission, bins=30, color='#2680d3', edgecolor='black')
plt.axvline(dk_hourly_2022.total_direct_carbon_emission.mean(), color='#00347c', linestyle='dashed', linewidth=2, label=f'Média: {dk_hourly_2022.total_direct_carbon_emission.mean():.2f}')
plt.axvline(dk_hourly_2022.total_direct_carbon_emission.median(), color='#d88523', linestyle='dotted', linewidth=2, label=f'Mediana: {dk_hourly_2022.total_direct_carbon_emission.median():.2f}')
plt.title('Dinamarca - Histograma - Distribuição das Emissões Diretas (2022)')
plt.xlabel('Emissão Direta (gCO₂/kWh)')
plt.ylabel('Frequência')
plt.legend()
plt.tight_layout()
plt.show()

# %%
sns.boxplot(dk_hourly_2022.total_direct_carbon_emission)
# Out:
# <Axes: ylabel='total_direct_carbon_emission'>

# %% [markdown]
# ### 2023

# %%
dk_hourly_2023 = dk_hourly[dk_hourly.year == 2023]

correlation = dk_hourly_2023.hour.corr(dk_hourly_2023.total_direct_carbon_emission)
mean = dk_hourly_2023.total_direct_carbon_emission.mean()
median = dk_hourly_2023.total_direct_carbon_emission.median()
std = dk_hourly_2023.total_direct_carbon_emission.std()
variance = std**2
cv = (std/mean)*100

plt.figure(figsize=(15, 4))
plt.plot(dk_hourly_2023.hour, dk_hourly_2023.total_direct_carbon_emission, 
         linewidth=1.5, color='#00347c', marker='o', markersize=7, 
         markerfacecolor='white', markeredgewidth=1)

plt.axhline(mean, color='#2680d3', linestyle='dotted', linewidth=2, label=f'Média: {mean:.2f} gCO₂/kWh')
plt.axhline(median, color='#d88523', linestyle='dashdot', linewidth=2, label=f'Mediana: {median:.2f} gCO₂/kWh')

custom_lines = [
    Line2D([0], [0], color='none', label=f'Variância: {variance:.2f} (gCO₂/kWh)²'),
    Line2D([0], [0], color='none', label=f'Desvio Padrão: {std:.2f} gCO₂/kWh'),
    Line2D([0], [0], color='none', label=f'CV: {cv:.2f}%')
]

plt.legend(handles=plt.gca().get_legend_handles_labels()[0] + custom_lines)

plt.title(f'Dinamarca - Emissão Direta por Hora - 2023 | Coef. de Correlação Hora x Emissão Direta = {correlation:.2f} (Baixo)')
plt.xlabel('Hora')
plt.ylabel('Emissão Direta (gCO₂/kWh)')
plt.xticks(range(24))
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.hist(dk_hourly_2023.total_direct_carbon_emission, bins=30, color='#2680d3', edgecolor='black')
plt.axvline(dk_hourly_2023.total_direct_carbon_emission.mean(), color='#00347c', linestyle='dashed', linewidth=2, label=f'Média: {dk_hourly_2023.total_direct_carbon_emission.mean():.2f}')
plt.axvline(dk_hourly_2023.total_direct_carbon_emission.median(), color='#d88523', linestyle='dotted', linewidth=2, label=f'Mediana: {dk_hourly_2023.total_direct_carbon_emission.median():.2f}')
plt.title('Dinamarca - Histograma - Distribuição das Emissões Diretas (2023)')
plt.xlabel('Emissão Direta (gCO₂/kWh)')
plt.ylabel('Frequência')
plt.legend()
plt.tight_layout()
plt.show()

# %%
sns.boxplot(dk_hourly_2023.total_direct_carbon_emission)
# Out:
# <Axes: ylabel='total_direct_carbon_emission'>

# %% [markdown]
# ### 2024

# %%
dk_hourly_2024 = dk_hourly[dk_hourly.year == 2024]

correlation = dk_hourly_2024.hour.corr(dk_hourly_2024.total_direct_carbon_emission)
mean = dk_hourly_2024.total_direct_carbon_emission.mean()
median = dk_hourly_2024.total_direct_carbon_emission.median()
std = dk_hourly_2024.total_direct_carbon_emission.std()
variance = std**2
cv = (std/mean)*100

plt.figure(figsize=(15, 4))
plt.plot(dk_hourly_2024.hour, dk_hourly_2024.total_direct_carbon_emission, 
         linewidth=1.5, color='#00347c', marker='o', markersize=7, 
         markerfacecolor='white', markeredgewidth=1)

plt.axhline(mean, color='#2680d3', linestyle='dotted', linewidth=2, label=f'Média: {mean:.2f} gCO₂/kWh')
plt.axhline(median, color='#d88523', linestyle='dashdot', linewidth=2, label=f'Mediana: {median:.2f} gCO₂/kWh')

custom_lines = [
    Line2D([0], [0], color='none', label=f'Variância: {variance:.2f} (gCO₂/kWh)²'),
    Line2D([0], [0], color='none', label=f'Desvio Padrão: {std:.2f} gCO₂/kWh'),
    Line2D([0], [0], color='none', label=f'CV: {cv:.2f}%')
]

plt.legend(handles=plt.gca().get_legend_handles_labels()[0] + custom_lines)

plt.title(f'Dinamarca - Emissão Direta por Hora - 2024 | Coef. de Correlação Hora x Emissão Direta = {correlation:.2f} (Baixo)')
plt.xlabel('Hora')
plt.ylabel('Emissão Direta (gCO₂/kWh)')
plt.xticks(range(24))
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.hist(dk_hourly_2024.total_direct_carbon_emission, bins=30, color='#2680d3', edgecolor='black')
plt.axvline(dk_hourly_2024.total_direct_carbon_emission.mean(), color='#00347c', linestyle='dashed', linewidth=2, label=f'Média: {dk_hourly_2024.total_direct_carbon_emission.mean():.2f}')
plt.axvline(dk_hourly_2024.total_direct_carbon_emission.median(), color='#d88523', linestyle='dotted', linewidth=2, label=f'Mediana: {dk_hourly_2024.total_direct_carbon_emission.median():.2f}')
plt.title('Dinamarca - Histograma - Distribuição das Emissões Diretas (2024)')
plt.xlabel('Emissão Direta (gCO₂/kWh)')
plt.ylabel('Frequência')
plt.legend()
plt.tight_layout()
plt.show()

# %%
sns.boxplot(dk_hourly_2024.total_direct_carbon_emission)
# Out:
# <Axes: ylabel='total_direct_carbon_emission'>
